# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jan 20 14:23:40 2017

@author: JTay
"""

import numpy as np
from sklearn.neural_network import MLPClassifier
import sklearn.model_selection as ms
import pandas as pd
from helpers import  basicResults,makeTimingCurve,iterationLC
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel


contra = pd.read_csv('./data/cmc.data.txt')      
col_names_contra = ['wifes_age', 'wifes_edu', 'husbs_edu', 'num_children_born', 'wifes_religion', 'wife_employed', 'husbs_occup', 'SOL_index', 'media_expose', 'contra_method']
contra.columns = col_names_contra
contra[col_names_contra] = contra[col_names_contra].astype(np.int64)
contra = pd.get_dummies(contra, columns = ['husbs_occup'], prefix = 'husbs_occup')

contraX = contra.drop('contra_method',1).copy().values
contraY = contra['contra_method'].copy().values


cancer = pd.read_csv('./data/breast_cancer.csv')  
cancer = pd.get_dummies(cancer, columns = ['class'], prefix = 'class')
cancer['class'] = cancer['class_2.0']
cancer.drop(['class_2.0', 'class_4.0'], axis = 1, inplace = True)
cancer = cancer.astype(np.int64)

cancerX = cancer.drop('class',1).copy().values
cancerY = cancer['class'].copy().values

contra_trgX, contra_tstX, contra_trgY, contra_tstY = ms.train_test_split(contraX, contraY, test_size=0.3, random_state=0,stratify=contraY)     
cancer_trgX, cancer_tstX, cancer_trgY, cancer_tstY = ms.train_test_split(cancerX, cancerY, test_size=0.3, random_state=0,stratify=cancerY)     

pipeO = Pipeline([('Scale',StandardScaler()),
                 ('MLP',MLPClassifier(max_iter=2000,early_stopping=True,random_state=55))])
pipeC = Pipeline([('Scale',StandardScaler()),
                 ('MLP',MLPClassifier(max_iter=2000,early_stopping=True,random_state=55))])

d = contraX.shape[1]
hiddens_contra = [(h,)*l for l in [1,2,3] for h in [d,d//2,d*2]]

d = cancerX.shape[1]
hiddens_cancer = [(h,)*l for l in [1,2,3] for h in [d,d//2,d*2]]

alphas = [10**-x for x in np.arange(-1,5.01,1/2)]

params_contra = {'MLP__activation':['relu','logistic'],'MLP__alpha':alphas,'MLP__hidden_layer_sizes':hiddens_contra}
params_cancer = {'MLP__activation':['relu','logistic'],'MLP__alpha':alphas,'MLP__hidden_layer_sizes':hiddens_cancer}

contra_clf = basicResults(pipeO,contra_trgX,contra_trgY,contra_tstX,contra_tstY,params_contra,'ANN','contra')        
cancer_clf = basicResults(pipeC,cancer_trgX,cancer_trgY,cancer_tstX,cancer_tstY,params_cancer,'ANN','cancer')        

contra_final_params =contra_clf.best_params_
contra_OF_params =contra_final_params.copy()
contra_OF_params['MLP__alpha'] = 0

cancer_final_params = cancer_clf.best_params_
cancer_OF_params =cancer_final_params.copy()
cancer_OF_params['MLP__alpha'] = 0

#raise

pipeC.set_params(**cancer_final_params)  
pipeC.set_params(**{'MLP__early_stopping':False})                   
makeTimingCurve(cancerX,cancerY,pipeC,'ANN','cancer')

pipeO.set_params(**contra_final_params)
pipeO.set_params(**{'MLP__early_stopping':False})                  
makeTimingCurve(contraX,contraY,pipeO,'ANN','contra')


pipeC.set_params(**cancer_final_params)
pipeC.set_params(**{'MLP__early_stopping':False})               
iterationLC(pipeC,cancer_trgX,cancer_trgY,cancer_tstX,cancer_tstY,{'MLP__max_iter':[2**x for x in range(12)]+[2100,2200,2300,2400,2500,2600,2700,2800,2900,3000]},'ANN','cancer')        

pipeO.set_params(**contra_final_params)
pipeO.set_params(**{'MLP__early_stopping':False})                  
iterationLC(pipeO,contra_trgX,contra_trgY,contra_tstX,contra_tstY,{'MLP__max_iter':[2**x for x in range(12)]+[2100,2200,2300,2400,2500,2600,2700,2800,2900,3000]},'ANN','contra')                


pipeC.set_params(**cancer_OF_params)
pipeC.set_params(**{'MLP__early_stopping':False})                  
iterationLC(pipeC,cancer_trgX,cancer_trgY,cancer_tstX,cancer_tstY,{'MLP__max_iter':[2**x for x in range(12)]+[2100,2200,2300,2400,2500,2600,2700,2800,2900,3000]},'ANN_OF','cancer')        

pipeO.set_params(**contra_OF_params)
pipeO.set_params(**{'MLP__early_stopping':False})               
iterationLC(pipeO,contra_trgX,contra_trgY,contra_tstX,contra_tstY,{'MLP__max_iter':[2**x for x in range(12)]+[2100,2200,2300,2400,2500,2600,2700,2800,2900,3000]},'ANN_OF','contra')
# Out:
# Fitting 5 folds for each of 234 candidates, totalling 1170 fits
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,), score=0.39639300809513583, total=   0.2s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,), score=0.4055448098001291, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,), score=0.35895300522960105, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,), score=0.38319740577854466, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12,), score=0.38548918029248286, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,), score=0.32124435847840105, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,), score=0.3288201160541586, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,), score=0.30327208252740173, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,), score=0.3471673254281948, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6,), score=0.31184407796101954, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,), score=0.38100866824271085, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,), score=0.3725911598252024, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,), score=0.36977039902571823, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,), score=0.36167167696561436, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24,), score=0.3881251862331746, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.3s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.3s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.3s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.3s remaining:    0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12), score=0.36458557203238057, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12), score=0.37552833297514154, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12), score=0.39354538290708513, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12), score=0.3204550093711146, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12), score=0.35611185017819735, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6), score=0.34461637653127014, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6), score=0.23550218497027017, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6), score=0.32753062540296585, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6), score=0.34404516691718146, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6), score=0.2789907862969924, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24), score=0.3572426391575328, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24), score=0.34004943047496244, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24), score=0.3984078372376246, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24), score=0.35359488949507306, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24), score=0.3752290521405964, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12), score=0.35638297872340424, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12), score=0.3573500967117989, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12), score=0.3601708575112831, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12), score=0.31620553359683773, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(12, 12, 12), score=0.3462435448942196, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6), score=0.33333333333333337, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6), score=0.3333333333333334, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6), score=0.3333333333333334, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6), score=0.3333333333333332, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(6, 6, 6), score=0.33333333333333337, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24), score=0.3148148148148148, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24), score=0.2975589225589226, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24), score=0.31734006734006737, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24), score=0.32954545454545436, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=10.0, MLP__hidden_layer_sizes=(24, 24, 24), score=0.37483136366089265, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,), score=0.39220216347875925, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,), score=0.40386130811662735, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,), score=0.35895300522960105, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,), score=0.3844337434355805, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12,), score=0.38037788617428386, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,), score=0.32124435847840105, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,), score=0.3288201160541586, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,), score=0.30327208252740173, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,), score=0.3471673254281948, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6,), score=0.31184407796101954, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,), score=0.3856382978723404, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,), score=0.3763790386130812, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,), score=0.38197578623110545, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,), score=0.44427898086808054, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24,), score=0.3881251862331746, total=   0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12), score=0.3899455548391718, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12), score=0.38893366286983305, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12), score=0.3771939250662656, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12), score=0.3501804635454359, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12), score=0.39822694286659494, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6), score=0.34082849774339136, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6), score=0.23550218497027017, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6), score=0.32374274661508706, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6), score=0.3393503312364303, total=   0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6), score=0.29476341641385884, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24), score=0.37868937602980157, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24), score=0.33859875349237056, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24), score=0.4035210258614514, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24), score=0.3617482231995396, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24), score=0.3816425120772947, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12), score=0.37717601547388774, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12), score=0.3573500967117989, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12), score=0.35404577691811734, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12), score=0.3162055335968378, total=   0.0s
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(12, 12, 12), score=0.35348992170581384, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6), score=0.33333333333333337, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6), score=0.3333333333333334, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6), score=0.3333333333333334, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6), score=0.3333333333333332, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(6, 6, 6), score=0.33333333333333337, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24), score=0.324074074074074, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24), score=0.2975589225589226, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24), score=0.3194444444444445, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24), score=0.350885616730687, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24)
# [CV]  MLP__activation=relu, MLP__alpha=3.16227766017, MLP__hidden_layer_sizes=(24, 24, 24), score=0.3786627812854137, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,), score=0.41156243283902855, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,), score=0.40253599828067926, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,), score=0.4223350526542016, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,), score=0.38352678654270805, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12,), score=0.3957035566723681, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,), score=0.3283365570599613, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,), score=0.3288201160541586, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,), score=0.30327208252740173, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,), score=0.3471673254281948, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6,), score=0.31184407796101954, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,), score=0.4059030016476825, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,), score=0.3763790386130812, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,), score=0.378671466437424, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,), score=0.436703223292323, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(24,), score=0.3881251862331746, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12), score=0.4114102013038183, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12), score=0.40606418797908167, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12), score=0.3771939250662656, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12), score=0.3454856278646847, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(12, 12), score=0.4101376541776061, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6, 6), score=0.3479206963249517, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6, 6), score=0.24343613439358125, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6, 6)
# [CV]  MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6, 6), score=0.32374274661508706, total=   0.0s
# [CV] MLP__activation=relu, MLP__alpha=1.0, MLP__hidden_layer_sizes=(6, 6)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ...
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (4) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (8) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (8) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (16) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (16) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 1
# 2
# 4
# 8
# 16
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (32) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (32) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (64) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 32
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (64) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 64
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (128) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (128) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 128
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (256) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (256) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 256
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 512
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 1024
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2048
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2100
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2200
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2300
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2400
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2500
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2600
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2700
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2800
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2900
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/kmertan/miniconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 3000
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('Scale', StandardScaler(copy=True, with_mean=True, with_std=True)), ('MLP', MLPClassifier(activation='relu', alpha=0, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(12,), learning_rate='constant',
#        learning_rate_init=...       solver='adam', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'MLP__max_iter': [1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024, 2048, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=make_scorer(balanced_accuracy), verbose=10)
